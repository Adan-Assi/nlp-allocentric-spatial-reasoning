# %%
import geopandas as gpd

gpkg_path = '../data/manhattan/manhattan_geo_paths.gpkg'

# List all layers in the GeoPackage
import fiona
layers = fiona.listlayers(gpkg_path)
print(f"Available layers: {layers}")
# Out:
# Available layers: ['end_point', 'start_point', 'main_pivot', 'near_pivot', 'beyond_pivot', 'path_features']
